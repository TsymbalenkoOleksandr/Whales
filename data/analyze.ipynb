# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('data_set/train.csv')

# %%
# counts['id'] = data.groupby('Id').index.tolist
counts = pd.DataFrame(data.groupby('Id').agg('count').index.tolist(), columns=['Id'])
counts['size'] = data.groupby('Id').agg('count')['Image'].tolist()
counts.hist(bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002530656BC88>]],
#       dtype=object)

# %%
counts.tail(15)
# Out:
#              Id  size
# 4236  w_ff1b64c     5
# 4237  w_ff2c4a4     1
# 4238  w_ff2ca5c     1
# 4239  w_ff39e03     1
# 4240  w_ff5538f     1
# 4241  w_ff70408     4
# 4242  w_ff7630a     5
# 4243  w_ff94ad6     1
# 4244  w_ffa7427     3
# 4245  w_ffa78a5     5
# 4246  w_ffb4e3d     2
# 4247  w_ffbd74c     2
# 4248  w_ffcd98e     2
# 4249  w_ffda8b2     4
# 4250  w_ffdab7a     1

# %%
counts['size_add'] = 35 - counts['size']
counts['checked'] = ''
counts
# Out:
#              Id  size  size_add checked
# 0     new_whale   810      -775
# 1     w_0013924     3        32
# 2     w_001ebbc     1        34
# 3     w_002222a     2        33
# 4     w_002b682     1        34
# 5     w_002dc11     1        34
# 6     w_0087fdd     2        33
# 7     w_008c602     1        34
# 8     w_009dc00     2        33
# 9     w_00b621b     2        33
# 10    w_00c4901     1        34
# 11    w_00cb685     3        32
# 12    w_00d8453     1        34
# 13    w_00fbb4e     2        33
# 14    w_0103030     1        34
# 15    w_010a1fa     2        33
# 16    w_011d4b5     2        33
# 17    w_0122d85     1        34
# 18    w_01319fa     1        34
# 19    w_0134192     1        34
# 20    w_013bbcf     1        34
# 21    w_014250a     2        33
# 22    w_014a645     1        34
# 23    w_0156f27     1        34
# 24    w_015c991     1        34
# 25    w_015e3cf     1        34
# 26    w_01687a8     2        33
# 27    w_0175a35     1        34
# ...

# %%
counts.to_csv('results.csv')

# %%
counts[counts['size_add'] < 0]
# Out:
#           Id  size  size_add checked
# 0  new_whale   810      -775
